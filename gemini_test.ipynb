# %%
# import pkgutil
# from google.auth.transport.requests import AuthorizedSession
# from google.oauth2 import service_account
# import vertexai
# from vertexai.generative_models import GenerativeModel
# vertexAI = None

# # serviceAccount = pkgutil.get_data("cse290d-project-0b43ca431137.json")
# # print(serviceAccount)

# JSON_KEY = "cse290d-project-0b43ca431137.json"
# credentials = service_account.Credentials.from_service_account_file(JSON_KEY)
# vertexai.init(project=426063056218, location="us-central1", credentials=credentials)
# model = GenerativeModel("gemini-1.5-flash-002")
# print(model.generate_content("Why is sky blue?"))

# %%
# !python --version
# Out:
# Python 3.10.15

# %%
import os

'''
Important paths
'''
path_to_original_pascal3dp = '/srv/PASCAL3D+_release1.1/'

small_occluder_path = '/srv/occluder_libs_test_small.npz'
medium_occluder_path = '/srv/occluder_libs_test_medium.npz'
large_occluder_path = '/srv/occluder_libs_test_large.npz'

# just for now...
occluder_path = '/srv/occluder_libs_test_low.npz'

bg_list_path = path_to_original_pascal3dp + 'Image_sets/%s_imagenet_val.txt'
bg_img_path = path_to_original_pascal3dp + 'Images/%s_imagenet'
bg_anno_path = path_to_original_pascal3dp + 'Annotations/%s_imagenet'
bg_mask_path = path_to_original_pascal3dp + 'obj_mask/%s'

path_save = './results'
save_img_path = path_save + '/images'
save_anno_path = path_save + '/annotations'

# %%
# %pip install -q -U google-generativeai
# %pip install google-cloud-aiplatform
# %pip install --upgrade -q google-api-python-client google-auth-httplib2 google-auth-oauthlib
# %pip install mediapipe
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.18 requires protobuf<5,>=4.25.3, but you have protobuf 3.20.3 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-cloud-aiplatform in /opt/conda/lib/python3.10/site-packages (1.71.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.34.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.35.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (24.1)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.14.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.12.5)
# Requirement already satisfied: shapely<3.0.0dev in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.0.6)
# Requirement already satisfied: pydantic<3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.10.18)
# Requirement already satisfied: docstring-parser<1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (0.16)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.65.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.66.1)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.6.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (4.12.2)
# Requirement already satisfied: numpy<3,>=1.14 in /opt/conda/lib/python3.10/site-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.25.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.6.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mediapipe in /opt/conda/lib/python3.10/site-packages (0.10.18)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in /opt/conda/lib/python3.10/site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /opt/conda/lib/python3.10/site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in /opt/conda/lib/python3.10/site-packages (from mediapipe) (0.4.35)
# Requirement already satisfied: jaxlib in /opt/conda/lib/python3.10/site-packages (from mediapipe) (0.4.35)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mediapipe) (3.7.3)
# Requirement already satisfied: numpy<2 in /opt/conda/lib/python3.10/site-packages (from mediapipe) (1.25.2)
# Requirement already satisfied: opencv-contrib-python in /opt/conda/lib/python3.10/site-packages (from mediapipe) (4.10.0.84)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: sounddevice>=0.4.4 in /opt/conda/lib/python3.10/site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /opt/conda/lib/python3.10/site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from jax->mediapipe) (0.5.0)
# Requirement already satisfied: opt-einsum in /opt/conda/lib/python3.10/site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /opt/conda/lib/python3.10/site-packages (from jax->mediapipe) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mediapipe) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mediapipe) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mediapipe) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mediapipe) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 1.34.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5, but you have protobuf 4.25.5 which is incompatible.
# google-cloud-datastore 1.15.5 requires protobuf<4.0.0dev, but you have protobuf 4.25.5 which is incompatible.
# kfp 2.5.0 requires protobuf<4,>=3.13.0, but you have protobuf 4.25.5 which is incompatible.
# kfp-pipeline-spec 0.2.2 requires protobuf<4,>=3.13.0, but you have protobuf 4.25.5 which is incompatible.
# Successfully installed protobuf-4.25.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow

SCOPES = ['https://www.googleapis.com/auth/generative-language.retriever']

def load_creds():
    """Converts `client_secret.json` to a credential object.

    This function caches the generated tokens to minimize the use of the
    consent screen.
    """
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'client_secret.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())
    return creds

# %%
import pprint
import google.generativeai as genai

creds = load_creds()

genai.configure(credentials=creds)

# print()
# print('Available base models:', [m.name for m in genai.list_models()])

# %%
# # from IPython.display import Image
# from PIL import Image
# import numpy as np

# data = np.load('/srv/occluder_libs_test_small.npz', allow_pickle=True)
# # print(type(data['images'][0]))
# # image = mp.Image(image_format=mp.ImageFormat.SRGB, data=np.asarray(data['images'][0]))
# # image = Image.fromarray(data['images'][0])

# %%
# ## FOR FOREGROUND LABELING

# import PIL.Image
# from matplotlib import pyplot as plt

# # image = PIL.Image.open('skater.jpg')
# # print(image)

# # image = data['images'][0]
# # plt.imshow(image, interpolation='nearest')
# # plt.show()

# # model = genai.GenerativeModel("gemini-1.5-pro")
# # prompt = "In one word, what do you see in this image"
# # response = model.generate_content([prompt, image])
# # print("RESPONSE", response)
# # print(response.text)
# # Markdown(">" + response.text)
# # print(model.generate_content("Why is sky blue?"))
# # myfile = genai.upload_file("skier.jpg")
# # print(f"{myfile=}")

# %%
# from PIL import Image
# import numpy as np
# from matplotlib import pyplot as plt
# # import system

# data = np.load('/srv/occluder_libs_test_small.npz', allow_pickle=True)

# model = genai.GenerativeModel("gemini-1.5-pro")

# label_csv = open("foreground_labels.csv", "w")
# label_csv.write("index,label\n")

# for i, option in enumerate(data['images']):
#     if i > 500:
#         break
#     # print(option)
#     plt.imshow(option, interpolation='nearest')
#     plt.show()
#     image = Image.fromarray(option)
#     # prompt = "In one word, what do you see in this image"
#     prompt = "You are an image classifier. Given this image, in one word what is a generic category would you classify this image as?"
#     response = model.generate_content([prompt, image])
#     # print(response.text)
#     if (not response.prompt_feedback):
#         csv_entry = f"{i},{response.text}\n"
#         print(csv_entry)
#         label_csv.write(csv_entry)
#     # system('cls')
    
    
# label_csv.close()

# %%
# import csv

# labels = set()

# with open('foreground_labels_small.csv', 'r') as file:
#     csv_reader = csv.reader(file)
#     # print(csv_reader.to_list())
#     first_row = True
#     for row in csv_reader:
#         if first_row:
#             first_row = False
#             continue
#         # print(row)
#         labels.add(row[1])
#         # break
        
# # print(list(labels))
# prompt = "You will be a given a list of foreground objects, and you are suppsoe to choose a category from that list to cover the subject in the image provided. Your answer should be one category from the list provided and should be a one word answer. You have to make a selection, and cannot say no. The list is: " + str(list(labels))
# print(prompt)

# %%
# ## FOR FOREGROUND IMAGE SEARCH

# import PIL.Image

# skier_image = PIL.Image.open('skater.jpg')
# print(skier_image)

# model = genai.GenerativeModel("gemini-1.5-pro")
# prompt = "The goal is for you to go through a list of foreground objects, and select which one is the most realistic to cover the object in the image provided. The list of foreground objects are: [car, cat, dog, bird, bus, baby, tree]. You are forced to choose an option, and it should be a one word answer."
# prompt = "You will be a given a list of foreground objects, and you are suppsoe to choose a category from that list to cover the subject in the image provided. Your answer should be one category from the list provided and should be a one word answer. You have to make a selection, and cannot say no. The list is [car, cat, dog, bird, bus, baby, tree]."
# response = model.generate_content([prompt, skier_image])
# print(response)
# # Markdown(">" + response.text)
# # print(model.generate_content("Why is sky blue?"))
# # myfile = genai.upload_file("skier.jpg")
# # print(f"{myfile=}")

# %%
#import BboxTools as bbt
import os
import csv
from collections import defaultdict
from PIL import Image
import scipy
import random

def get_labels():
    all_labels = {}

    
    for sizing in ["small", "medium", "large"]:

        with open('foreground_labels_' + sizing + '.csv', 'r') as file:
            labels = defaultdict(list)
            csv_reader = csv.reader(file)
            # print(csv_reader.to_list())
            first_row = True
            for row in csv_reader:
                if first_row:
                    first_row = False
                    continue
                # print(row)
                labels[row[1]].append(int(row[0]))
                # break
            all_labels[sizing] = labels
        
    return all_labels

def load_one_annotation(anno_path):
    a = scipy.io.loadmat(anno_path)
    # I added the astype int here....
    bbox_ = a['record'][0][0][1][0][0][1][0].astype(int)
    w = a['record']['size'][0][0][0][0][0]
    h = a['record']['size'][0][0][0][0][1]
    num_obj = len(a['record'][0][0][1][0])
    return w, h, bbox_, num_obj != 1

# the only reason we have bg_mask_dir is in case we need it for segmentation masks...
def generate_dataset(file_list, bg_img_dir, bg_anno_dir, file_obj, category):
    print("CATEGORY", category)
    
    all_labels = get_labels()
    # print(all_labels)
    # return
    # small_label_titles = list(all_labels["small"].keys())
    # medium_label_titles = list(all_labels["medium"].keys())
    # large_label_titles = list(all_labels["large"].keys())
    
    # print(small_label_titles)
    
    # return
    
    # print(label_titles)

    model = genai.GenerativeModel("gemini-1.5-pro")

    # print(prompt)
    # return
    
    # os.makedirs(save_img_dir, exist_ok=True)
    # os.makedirs(save_anno_dir, exist_ok=True)

    # make a different directory for each range
    # for range_label in occlusion_ranges.keys():
    #     os.makedirs(save_img_dir + "/" + range_label, exist_ok=True)
    #     os.makedirs(save_anno_dir + "/" + range_label, exist_ok=True)
    
    # DO 100 PER CATEGORY
    
    """
    for every file name:
        csv_output = bg_image_path
        for every label size:
            run gemini
            csv_output += ,rand_index
    """
    
    for file_name in file_list[:min(100, len(file_list))]:
        
        bg_w, bg_h, bg_bbox, flag_ = load_one_annotation(os.path.join(bg_anno_dir, file_name + '.mat'))

        if flag_:
            # record_file.write('Skipped %s for multi objects\n' % file_name)
            continue
            
        bg_img_path = os.path.join(bg_img_dir, file_name + '.JPEG')
        # print(bg_img_path)
        bg_img = Image.open(bg_img_path)
        
        csv_output = bg_img_path
        
        for sizing in ["small", "medium", "large"]:
            label_titles = list(all_labels[sizing].keys())
            tmp_category = category if category != "motorbike" else "Motorcycle"
            tmp_category = tmp_category.capitalize()
            # print("tmp", tmp_category)
            if tmp_category in label_titles:
                label_titles.remove(tmp_category)
                print("removing: ", tmp_category)
            # print(label_titles)
            prompt = "You will be a given a list of foreground objects, and you are suppose to choose a category from that list to cover the subject in the image provided. Your answer should be one category from the list provided and should be a one word answer. You have to make a selection, and cannot say no. The list is: " + str(label_titles)
            response = model.generate_content([prompt, bg_img])
            fg_category = response.text.strip()
            # print(fg_category)
            if fg_category in label_titles:
                fg_category_indexes = all_labels[sizing][fg_category]
                rand_index = random.choice(fg_category_indexes)
                # csv_output = bg_img_path+","+str(rand_index)+"\n"
                # print("HERE HERE")
                # print(csv_output)
                csv_output += ","+str(rand_index)
                print(fg_category)
            # print(fg_category_indexes)
        csv_output += "\n"
        print(csv_output)
        file_obj.write(csv_output)
        # bg_mask = np.array(Image.open(os.path.join(bg_mask_dir, file_name + '.JPEG')))

        #if not bg_mask.shape[0] == bg_img.shape[0] and bg_mask.shape[1] == bg_img.shape[1]:
            #bg_mask = cv2.resize(mask, (bg_img.shape[1], bg_img.shape[0]), interpolation=cv2.INTER_NEAREST)

        # not sure why this is necessary, took from OccludedPascal3D+ code
        #bg_bbox = bbt.from_numpy(bg_bbox, image_boundary=img.shape[0:2], sorts=('x0', 'y0', 'x1', 'y1'))

        # generate_composite_image(cate, bg_img, bg_w, bg_h, bg_bbox, save_img_path)
    # pair_csv.close()

# %%
categories = ['bicycle', 'bus', 'car', 'motorbike', 'train']
path_to_original_pascal3dp = '/srv/PASCAL3D+_release1.1/'
bg_list_path = path_to_original_pascal3dp + 'Image_sets/%s_imagenet_val.txt'
bg_anno_path = path_to_original_pascal3dp + 'Annotations/%s_imagenet'

pair_csv = open("bg_fg_pair.csv", "w")
pair_csv.write("image_name,fg_index_small,fg_index_medium,fg_index_large\n")

for cate in categories:
    print('Start cate: ', cate)
    # tem = open('generating_record_%s_1030.txt' % cate, 'w')
    file_list_ = open(bg_list_path % cate).readlines()
    file_list_ = [tem.strip('\n') for tem in file_list_]
    bg_anno_path_ = bg_anno_path % cate
    bg_img_path_ = bg_img_path % cate

    generate_dataset(file_list_, bg_img_path_, bg_anno_path_, pair_csv, cate)
    
pair_csv.close()
# Out:
# Start cate:  bicycle
# CATEGORY bicycle
# Cycling
# Cycling
# People
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10027.JPEG,419,451,207
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10155.JPEG,419,295,425
#
# Cycling
# Cycling
# People
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10164.JPEG,419,295,206
#
# Cycling
# Cycling
# Person
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10218.JPEG,44,295,38
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10227.JPEG,412,295,409
#
# Cycling
# Cycling
# People
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10230.JPEG,44,451,184
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10294.JPEG,412,295,425
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1034.JPEG,44,295,412
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10373.JPEG,98,295,412
#
# Cycling
# Cycling
# People
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10394.JPEG,419,274,206
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10434.JPEG,98,451,79
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10521.JPEG,65,451,412
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10526.JPEG,412,451,452
#
# Cycling
# Cycling
# Woman
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10544.JPEG,98,451,483
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10611.JPEG,65,295,412
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10662.JPEG,98,274,344
#
# Cycling
# Cycling
# Man
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1073.JPEG,65,274,0
#
# Cycling
# Cycling
# People
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10743.JPEG,65,451,184
#
# Man
# Cycling
# Man
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10753.JPEG,446,295,183
#
# Cycling
# Cycling
# Beach
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10900.JPEG,98,295,468
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10952.JPEG,65,274,342
#
# Cycling
# Cycling
# Beach
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10979.JPEG,65,451,468
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_10989.JPEG,98,274,412
#
# Cycling
# Cycling
# Person
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1102.JPEG,412,451,114
#
# Cycling
# Cycling
# Person
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1107.JPEG,44,451,215
#
# Cycling
# Cycling
# People
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11107.JPEG,98,274,206
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11114.JPEG,412,295,425
#
# Cycling
# Cycling
# Sculpture
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11156.JPEG,65,295,407
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11165.JPEG,44,295,425
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11226.JPEG,44,451,336
#
# Cycling
# Cycling
# Person
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11291.JPEG,412,451,263
#
# Cycling
# Cycling
# Sculpture
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1130.JPEG,44,295,407
#
# Cycling
# Cycling
# Sports
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11341.JPEG,44,451,330
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11443.JPEG,412,451,453
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11448.JPEG,419,451,412
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11520.JPEG,412,274,412
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11525.JPEG,44,451,425
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11645.JPEG,44,295,425
#
# Cycling
# Cycling
# Person
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11660.JPEG,65,295,145
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11763.JPEG,98,451,412
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11773.JPEG,412,274,412
#
# Cycling
# Cycling
# Man
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11803.JPEG,44,295,0
#
# Cycling
# Cycling
# Beach
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11848.JPEG,98,295,468
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11854.JPEG,419,274,412
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_11865.JPEG,412,295,425
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1189.JPEG,98,274,425
#
# Cycling
# Cycling
# Person
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_12019.JPEG,412,274,250
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_12038.JPEG,412,274,218
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1205.JPEG,44,295,425
#
# Man
# Cycling
# Man
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_12054.JPEG,55,274,0
#
# Cycling
# Cycling
# People
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_12154.JPEG,65,295,206
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_12447.JPEG,65,451,412
#
# Cycling
# Cycling
# Beach
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_12489.JPEG,412,451,468
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_12604.JPEG,44,274,56
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_12655.JPEG,44,274,441
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_12716.JPEG,412,295,425
#
# Cycling
# Cycling
# People
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_12736.JPEG,419,295,184
#
# Cycling
# Cycling
# Stunt
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_12760.JPEG,65,274,100
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1278.JPEG,412,451,79
#
# Man
# Cycling
# Man
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1303.JPEG,55,274,128
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1362.JPEG,44,451,425
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1372.JPEG,419,274,425
#
# Cycling
# Cycling
# Beach
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1396.JPEG,412,451,468
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1446.JPEG,412,295,425
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1613.JPEG,65,451,425
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1633.JPEG,98,451,425
#
# Cycling
# Cycling
# Sculpture
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1688.JPEG,65,295,407
#
# Woman
# Woman
# Woman
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1704.JPEG,10,500,483
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_17153.JPEG,419,451,92
#
# Cycling
# Cycling
# Person
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1765.JPEG,419,451,7
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1798.JPEG,419,451,453
#
# Cycling
# Cycling
# Girl
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1838.JPEG,419,295,251
#
# Cycling
# Cycling
# Sports
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1863.JPEG,419,274,59
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_187.JPEG,44,274,425
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1895.JPEG,98,295,425
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_1958.JPEG,65,451,412
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_2190.JPEG,65,295,412
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_2352.JPEG,98,451,425
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_24515.JPEG,419,451,56
#
# Cycling
# Cycling
# Cat
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_2538.JPEG,65,274,118
#
# Cycling
# Cycling
# People
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_2718.JPEG,65,451,184
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_2862.JPEG,412,295,425
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_2873.JPEG,419,274,412
#
# Cycling
# Cycling
# Man
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_2989.JPEG,419,274,128
#
# Cycling
# Cycling
# Man
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_3026.JPEG,98,274,183
#
# Cycling
# Cycling
# Plant
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_3101.JPEG,419,295,173
#
# Cycling
# Cycling
# Person
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_3104.JPEG,419,274,226
#
# Cycling
# Cycling
# Man
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_3123.JPEG,419,295,128
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_3132.JPEG,44,451,425
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_31967.JPEG,98,295,412
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_3211.JPEG,65,451,425
#
# Man
# Cycling
# Man
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_327.JPEG,446,274,128
#
# Cycling
# Cycling
# People
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_3460.JPEG,419,295,184
#
# Cycling
# Cycling
# Motorcycle
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_3480.JPEG,65,274,412
#
# Cycling
# Cycling
# Sports
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_3515.JPEG,98,451,59
#
# Cycling
# Cycling
# Racing
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_35466.JPEG,65,295,425
#
# Cycling
# Cycling
# Person
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_3609.JPEG,419,451,422
#
# Cycling
# Cycling
# Vendor
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_3612.JPEG,65,295,227
#
# Man
# Cycling
# Man
# /srv/PASCAL3D+_release1.1/Images/bicycle_imagenet/n02834778_3637.JPEG,446,451,128
#
# Start cate:  bus
# CATEGORY bus
# Person
# Building
# Person
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_10146.JPEG,310,375,300
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_10176.JPEG,474,484,184
#
# Parking
# Holiday
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_10455.JPEG,425,220,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_105849.JPEG,425,433,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_10641.JPEG,392,314,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_10686.JPEG,425,433,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_106956.JPEG,425,433,184
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_107743.JPEG,368,354,206
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_10943.JPEG,474,286,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_11049.JPEG,425,433,206
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_11237.JPEG,368,460,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_11522.JPEG,223,391,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_11582.JPEG,425,354,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_11721.JPEG,392,265,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_11779.JPEG,425,433,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_11831.JPEG,425,354,184
#
# Parking
# Furniture
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_12163.JPEG,425,192,206
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_12170.JPEG,57,286,207
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_12195.JPEG,474,354,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_1221.JPEG,57,314,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_12327.JPEG,425,354,184
#
# Woman
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_1299.JPEG,245,433,165
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_1367.JPEG,425,354,207
#
# Person
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_14403.JPEG,416,433,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_1474.JPEG,64,461,206
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_15448.JPEG,432,265,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_15583.JPEG,425,354,206
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_15763.JPEG,428,191,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_1665.JPEG,425,433,184
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_17453.JPEG,425,375,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_1752.JPEG,425,354,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_18911.JPEG,425,354,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_19176.JPEG,425,433,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_2083.JPEG,425,433,206
#
# Person
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_2233.JPEG,254,354,206
#
# People
# Holiday
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_22519.JPEG,474,220,206
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_22520.JPEG,54,265,184
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_234.JPEG,392,433,207
#
# Man
# Work
# Man
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_250.JPEG,275,433,128
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_25566.JPEG,474,433,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_263.JPEG,425,433,206
#
# People
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_2652.JPEG,432,375,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_2657.JPEG,425,433,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_27321.JPEG,425,433,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_27632.JPEG,432,461,206
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_27678.JPEG,428,354,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_27751.JPEG,392,242,206
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_28382.JPEG,432,460,207
#
# Parking
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_28622.JPEG,425,433,211
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_29310.JPEG,64,265,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_30444.JPEG,425,354,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_30505.JPEG,474,449,206
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_3060.JPEG,368,354,184
#
# Person
# Work
# Man
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_30955.JPEG,353,433,0
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_31015.JPEG,425,354,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_31134.JPEG,425,354,207
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_31580.JPEG,425,375,184
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_31709.JPEG,425,375,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_3182.JPEG,425,433,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_32040.JPEG,425,433,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_3207.JPEG,425,354,184
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_32406.JPEG,425,375,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_32503.JPEG,425,354,207
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_32632.JPEG,425,375,184
#
# Person
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_32650.JPEG,251,433,87
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_32676.JPEG,425,354,206
#
# Person
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_3289.JPEG,178,354,206
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_33050.JPEG,474,242,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_33093.JPEG,425,354,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_33307.JPEG,425,354,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_33400.JPEG,425,433,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_33540.JPEG,425,354,184
#
# Horse
# Horse
# Horse
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_33800.JPEG,497,420,395
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_33851.JPEG,425,354,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_34311.JPEG,425,433,184
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_34324.JPEG,425,375,206
#
# Parking
# Recreation
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_34753.JPEG,425,496,207
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_34936.JPEG,64,354,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_35139.JPEG,425,354,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_35198.JPEG,57,460,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_3525.JPEG,425,354,206
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_35304.JPEG,432,354,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_35449.JPEG,64,449,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_35836.JPEG,425,354,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_3604.JPEG,425,354,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_36323.JPEG,425,354,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_36341.JPEG,392,286,184
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_36487.JPEG,432,433,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_37011.JPEG,425,433,206
#
# Parking
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_37081.JPEG,425,433,33
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_3738.JPEG,425,375,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_37501.JPEG,425,433,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_37624.JPEG,474,347,206
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_37753.JPEG,474,265,184
#
# Parking
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_37908.JPEG,425,354,141
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_37941.JPEG,368,433,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_37952.JPEG,425,433,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_38016.JPEG,425,433,207
#
# Plants
# Flowers
# People
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_38100.JPEG,257,39,184
#
# Parking
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/bus_imagenet/n02924116_3834.JPEG,425,433,160
#
# Start cate:  car
# CATEGORY car
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_10251.JPEG,425,354,207
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_10268.JPEG,425,354,425
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_10294.JPEG,64,318,207
#
# Parking
# Plants
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_10404.JPEG,425,481,499
#
# Person
# Person
# Man
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_10429.JPEG,401,362,0
#
# Parking
# People
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_105.JPEG,425,460,184
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_10557.JPEG,425,433,425
#
# Sculpture
# Holiday
# Sculpture
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_10572.JPEG,238,220,407
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_10637.JPEG,425,354,336
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_10911.JPEG,54,219,206
#
# Parking
# Recreation
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_10995.JPEG,425,496,425
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_11124.JPEG,425,375,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_11246.JPEG,425,433,206
#
# Medical
# Holiday
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_11539.JPEG,450,220,206
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_11561.JPEG,425,354,425
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_1178.JPEG,425,433,56
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_11830.JPEG,425,433,218
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_11983.JPEG,425,433,425
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_11997.JPEG,425,433,425
#
# Parking
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_12044.JPEG,425,354,300
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_12311.JPEG,425,433,425
#
# Person
# Person
# Person
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_12348.JPEG,176,361,385
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_12532.JPEG,425,354,206
#
# Police
# Work
# Police
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_12546.JPEG,278,354,448
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_126.JPEG,425,375,206
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_12610.JPEG,425,433,425
#
# Parking
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_12731.JPEG,425,354,215
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_12779.JPEG,425,354,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_12813.JPEG,425,433,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_12925.JPEG,425,354,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_13055.JPEG,425,354,207
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_13150.JPEG,425,354,425
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_13301.JPEG,425,433,207
#
# Parking
# Building
# Family
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_13427.JPEG,425,375,356
#
# Parking
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_1354.JPEG,425,433,34
#
# Flowers
# Flowers
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_13662.JPEG,437,39,342
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_1392.JPEG,425,433,425
#
# Parking
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_14121.JPEG,425,433,87
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_14233.JPEG,425,354,206
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_14335.JPEG,425,375,206
#
# Parking
# Plants
# Cattle
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_14509.JPEG,425,481,352
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_14627.JPEG,425,433,184
#
# Parking
# Work
# Sculpture
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_14632.JPEG,425,433,407
#
# Parking
# People
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_14653.JPEG,425,372,184
#
# Parking
# Holiday
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_14756.JPEG,425,220,206
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_149.JPEG,64,449,207
#
# Parking
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_15146.JPEG,425,354,211
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_15249.JPEG,425,433,409
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_15300.JPEG,425,433,425
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_15544.JPEG,425,433,342
#
# Parking
# Work
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_15689.JPEG,425,433
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_15771.JPEG,428,191,184
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_15962.JPEG,425,354,426
#
# Parking
# People
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_15976.JPEG,425,449,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_16015.JPEG,425,354,184
#
# Parking
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_1609.JPEG,425,433,341
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_1649.JPEG,425,354,425
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_16978.JPEG,425,433,206
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_1748.JPEG,425,433,425
#
# Parking
# Work
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_17560.JPEG,425,433
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_17776.JPEG,425,354,342
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_17866.JPEG,425,354,207
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_17956.JPEG,425,354,344
#
# Parking
# Building
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_18128.JPEG,425,375,425
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_18183.JPEG,425,354,425
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_18207.JPEG,425,433,425
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_1823.JPEG,425,354,425
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_18318.JPEG,425,354,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_1835.JPEG,425,433,207
#
# Person
# Person
# Person
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_1838.JPEG,411,452,122
#
# Person
# Person
# Person
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_18387.JPEG,251,228,250
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_18706.JPEG,425,354,425
#
# Parking
# Building
# Houseplant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_1893.JPEG,425,375,335
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_19107.JPEG,425,354,79
#
# Parking
# Building
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_19376.JPEG,425,375,92
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_20022.JPEG,425,354,425
#
# Dog
# Dogs
# Dogs
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_2013.JPEG,283,49,400
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_20640.JPEG,425,354,173
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_20806.JPEG,425,433,453
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_20833.JPEG,425,433,425
#
# Parking
# People
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_21147.JPEG,425,460,207
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_2168.JPEG,425,354,499
#
# Parking
# Work
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_21811.JPEG,425,433
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_21859.JPEG,425,433,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_21929.JPEG,425,433,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_21965.JPEG,425,433,184
#
# Plants
# Plants
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_2216.JPEG,257,481,453
#
# Parking
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_22292.JPEG,425,354,328
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_2233.JPEG,425,433,206
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_22333.JPEG,425,433,342
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_22343.JPEG,425,354,425
#
# Person
# Person
# Man
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_22395.JPEG,105,361,128
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_22413.JPEG,425,354,425
#
# Parking
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_22580.JPEG,425,433,56
#
# Parking
# Plants
# Plant
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_22675.JPEG,425,481,76
#
# Parking
# Holiday
# Family
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_2271.JPEG,425,220,356
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_23154.JPEG,425,433,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_23466.JPEG,425,354,184
#
# Person
# Person
# Person
# /srv/PASCAL3D+_release1.1/Images/car_imagenet/n02814533_23592.JPEG,40,298,263
#
# Start cate:  motorbike
# CATEGORY motorbike
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10023.JPEG,425,359,425
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10042.JPEG,412,359,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Stunt
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10050.JPEG,305,359,100
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10061.JPEG,98,359,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10075.JPEG,425,360,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10146.JPEG,425,360,425
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Work
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10381.JPEG,44,433,82
#
# removing:  Motorcycle
# Man
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Man
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10394.JPEG,55,360,128
#
# removing:  Motorcycle
# Animal
# removing:  Motorcycle
# Animal
# removing:  Motorcycle
# Animal
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10466.JPEG,138,231,401
#
# removing:  Motorcycle
# Man
# removing:  Motorcycle
# Man
# removing:  Motorcycle
# Man
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10547.JPEG,55,293,0
#
# removing:  Motorcycle
# People
# removing:  Motorcycle
# People
# removing:  Motorcycle
# People
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10567.JPEG,57,372,184
#
# removing:  Motorcycle
# Man
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Man
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10647.JPEG,446,359,183
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# People
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10652.JPEG,419,360,207
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Plant
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10662.JPEG,65,360,393
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Man
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10667.JPEG,303,359,183
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10726.JPEG,44,360,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Man
# removing:  Motorcycle
# Man
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10738.JPEG,63,293,128
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Sports
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_10791.JPEG,305,331,425
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_11044.JPEG,44,359,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_11096.JPEG,425,360,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Man
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_11206.JPEG,305,359,183
#
# removing:  Motorcycle
# Fashion
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_11269.JPEG,469,359,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_11308.JPEG,425,359,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Plant
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_11311.JPEG,425,360,342
#
# removing:  Motorcycle
# Beach
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Beach
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_11390.JPEG,108,360,468
#
# removing:  Motorcycle
# Police
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Police
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_11481.JPEG,449,438,448
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Sports
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1150.JPEG,252,368,425
#
# removing:  Motorcycle
# People
# removing:  Motorcycle
# People
# removing:  Motorcycle
# People
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_11545.JPEG,428,347,207
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1183.JPEG,44,359,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_11830.JPEG,425,360,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_11966.JPEG,406,359,160
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12141.JPEG,425,359,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Man
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12238.JPEG,61,360,388
#
# removing:  Motorcycle
# People
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# People
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12252.JPEG,392,359,206
#
# removing:  Motorcycle
# Boy
# removing:  Motorcycle
# Child
# removing:  Motorcycle
# Child
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12353.JPEG,429,302,478
#
# removing:  Motorcycle
# Man
# removing:  Motorcycle
# Man
# removing:  Motorcycle
# Man
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12391.JPEG,446,345,183
#
# removing:  Motorcycle
# People
# removing:  Motorcycle
# People
# removing:  Motorcycle
# People
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12393.JPEG,428,460,207
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Horse
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12397.JPEG,425,359,152
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12399.JPEG,425,360,394
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12537.JPEG,425,359,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12557.JPEG,425,359,87
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12605.JPEG,425,359,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12640.JPEG,425,359,425
#
# removing:  Motorcycle
# Man
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Man
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12675.JPEG,275,360,183
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12676.JPEG,44,359,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Sports
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12712.JPEG,254,376,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Sports
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12777.JPEG,40,260,424
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Stunt
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12858.JPEG,425,360,100
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_12996.JPEG,419,359,425
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# People
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13015.JPEG,65,359,206
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13025.JPEG,425,359,425
#
# removing:  Motorcycle
# Police
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Police
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13294.JPEG,278,470,447
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13342.JPEG,425,359,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# People
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13361.JPEG,425,360,207
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13371.JPEG,412,360,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13416.JPEG,425,360,425
#
# removing:  Motorcycle
# Sports
# removing:  Motorcycle
# Sports
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13442.JPEG,122,250,425
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13462.JPEG,412,360,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13499.JPEG,35,360,7
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Equestrianism
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13502.JPEG,44,359,495
#
# removing:  Motorcycle
# People
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# People
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13675.JPEG,368,360,206
#
# removing:  Motorcycle
# Police
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Police
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13685.JPEG,449,408,449
#
# removing:  Motorcycle
# Plants
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13756.JPEG,257,360,82
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13786.JPEG,95,359,341
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13869.JPEG,425,360,291
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# People
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1390.JPEG,425,359,184
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_13929.JPEG,65,359,425
#
# removing:  Motorcycle
# People
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# People
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1409.JPEG,368,359,184
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14099.JPEG,419,359,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1410.JPEG,425,359,215
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14127.JPEG,419,360,425
#
# removing:  Motorcycle
# Sports
# removing:  Motorcycle
# Sports
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14346.JPEG,256,209,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14347.JPEG,425,359,422
#
# removing:  Motorcycle
# Man
# removing:  Motorcycle
# Man
# removing:  Motorcycle
# Man
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14420.JPEG,275,293,388
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14511.JPEG,419,360,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14583.JPEG,417,359,215
#
# removing:  Motorcycle
# Police
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Police
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14711.JPEG,449,359,447
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14794.JPEG,5,360,130
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14881.JPEG,98,359,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14883.JPEG,492,360,425
#
# removing:  Motorcycle
# People
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14972.JPEG,57,360,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_14985.JPEG,425,359,425
#
# removing:  Motorcycle
# Police
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Police
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1525.JPEG,449,359,448
#
# removing:  Motorcycle
# Woman
# removing:  Motorcycle
# Woman
# removing:  Motorcycle
# Woman
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_15396.JPEG,10,328,415
#
# removing:  Motorcycle
# Sports
# removing:  Motorcycle
# Sports
# removing:  Motorcycle
# Stunt
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_16366.JPEG,111,271,100
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1637.JPEG,425,359,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_16613.JPEG,135,359,177
#
# removing:  Motorcycle
# People
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# People
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1670.JPEG,428,359,207
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1688.JPEG,425,359,425
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Person
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_173.JPEG,425,360,250
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1734.JPEG,44,360,425
#
# removing:  Motorcycle
# Sports
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Stunt
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1768.JPEG,355,360,100
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1777.JPEG,425,360,425
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1872.JPEG,98,360,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Man
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_18905.JPEG,402,359,128
#
# removing:  Motorcycle
# Cycling
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Racing
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_1939.JPEG,412,359,425
#
# removing:  Motorcycle
# Person
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# Man
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_19720.JPEG,5,359,388
#
# removing:  Motorcycle
# Parking
# removing:  Motorcycle
# Motorcyclist
# removing:  Motorcycle
# People
# /srv/PASCAL3D+_release1.1/Images/motorbike_imagenet/n03790512_19797.JPEG,425,360,206
#
# Start cate:  train
# CATEGORY train
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_10040.JPEG,474,460,184
#
# Person
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_10135.JPEG,305,354,394
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_1020.JPEG,425,354,425
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_10463.JPEG,64,354,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_10492.JPEG,392,242,184
#
# Man
# Work
# Man
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_10534.JPEG,446,354,388
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_1055.JPEG,223,354,207
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_10718.JPEG,425,375,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_10741.JPEG,64,391,206
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_10820.JPEG,425,354,425
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_10862.JPEG,392,354,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_11211.JPEG,425,433,206
#
# Aviation
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_11214.JPEG,312,354,425
#
# Person
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_11301.JPEG,445,433,38
#
# Person
# Work
# Man
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_1195.JPEG,296,433,388
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_11950.JPEG,54,354,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12043.JPEG,425,433,206
#
# Woman
# Woman
# Woman
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_1218.JPEG,245,264,363
#
# Plants
# Work
# Plant
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12196.JPEG,257,433,393
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12253.JPEG,368,347,206
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12292.JPEG,428,433,184
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12305.JPEG,64,354,184
#
# Aviation
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12406.JPEG,312,354,425
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12409.JPEG,392,433,207
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12646.JPEG,392,354,206
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12669.JPEG,392,219,206
#
# Person
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12708.JPEG,273,137,207
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12736.JPEG,428,433,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12787.JPEG,425,433,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_12788.JPEG,432,372,206
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_13069.JPEG,57,354,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_13116.JPEG,54,449,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_13386.JPEG,54,191,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_13416.JPEG,425,354,207
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_13439.JPEG,425,354,425
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_13469.JPEG,432,314,206
#
# People
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_13624.JPEG,223,354,425
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_13655.JPEG,425,354,425
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_13733.JPEG,57,433,206
#
# Person
# Person
# Man
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_1434.JPEG,250,421,388
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_14929.JPEG,64,372,206
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_15075.JPEG,64,490,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_15091.JPEG,392,460,206
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_152.JPEG,392,433,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_1521.JPEG,425,433,206
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_15465.JPEG,64,354,184
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_15618.JPEG,474,433,206
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_15630.JPEG,425,375,207
#
# Aviation
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_15681.JPEG,312,354,425
#
# Person
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_15844.JPEG,393,433,206
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_15884.JPEG,425,433,425
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_15908.JPEG,425,354,425
#
# Parking
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_15950.JPEG,425,375,184
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16159.JPEG,223,354,207
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16250.JPEG,425,433,184
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16299.JPEG,425,354,425
#
# Plants
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16341.JPEG,257,354,425
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16342.JPEG,428,461,207
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16383.JPEG,425,354,425
#
# Person
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16466.JPEG,239,354,87
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_1647.JPEG,392,318,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16517.JPEG,428,137,206
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16534.JPEG,54,354,206
#
# People
# Building
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16547.JPEG,392,375,184
#
# Aviation
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16572.JPEG,312,354,425
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16584.JPEG,425,354,425
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16648.JPEG,432,219,207
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_1673.JPEG,432,354,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_1680.JPEG,425,433,184
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_16929.JPEG,432,433,206
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_1701.JPEG,223,354,184
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17037.JPEG,425,354,425
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17310.JPEG,64,354,184
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17356.JPEG,64,354,206
#
# Sculpture
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_1743.JPEG,238,433,425
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17437.JPEG,425,433,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17567.JPEG,64,449,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17614.JPEG,425,354,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17678.JPEG,392,242,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17724.JPEG,368,265,206
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17750.JPEG,425,433,425
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17757.JPEG,54,354,207
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17768.JPEG,432,354,207
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17902.JPEG,425,354,425
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_17980.JPEG,432,354,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_18040.JPEG,392,219,206
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_18095.JPEG,425,354,207
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_18184.JPEG,474,286,207
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_18319.JPEG,392,433,206
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_18329.JPEG,368,354,184
#
# Aviation
# Work
# Person
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_18383.JPEG,312,433,141
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_18471.JPEG,425,354,425
#
# Parking
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_18509.JPEG,425,354,425
#
# People
# Work
# Racing
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_1860.JPEG,392,354,425
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_18616.JPEG,432,265,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_187.JPEG,368,484,184
#
# Parking
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_19952.JPEG,425,433,184
#
# People
# People
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_206.JPEG,223,484,207
#
# People
# Work
# People
# /srv/PASCAL3D+_release1.1/Images/train_imagenet/n02917067_2193.JPEG,392,433,206
#
# People
# Work
